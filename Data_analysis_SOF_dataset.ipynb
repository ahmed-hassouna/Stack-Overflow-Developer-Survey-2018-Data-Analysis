# %% [markdown]
# # Reading the dataset

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import files

# %%
files.upload() #this will prompt you to upload the kaggle.json
# Out:
#      <input type="file" id="files-5c8a0d4c-8efe-48ac-8885-78ae12d50a9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c8a0d4c-8efe-48ac-8885-78ae12d50a9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 69 Sep  9 03:15 kaggle.json

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !pwd
# Out:
# /content

# %%
# !kaggle datasets download -d stackoverflow/stack-overflow-2018-developer-survey
# Out:
# ...
#  46% 9.00M/19.6M [00:00<00:00, 24.2MB/s]
# 100% 19.6M/19.6M [00:00<00:00, 49.4MB/s]

# %%
# !unzip /content/stack-overflow-2018-developer-survey.zip
# Out:
# Archive:  /content/stack-overflow-2018-developer-survey.zip
#   inflating: survey_results_public.csv
#   inflating: survey_results_schema.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/survey_results_public.csv')
df_schema = pd.read_csv('/content/survey_results_schema.csv')
df.head(3)
# Out:
# <ipython-input-73-760fc2a5fdfa>:1: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/survey_results_public.csv')
#    Respondent Hobby OpenSource         Country Student          Employment  \
# 0           1   Yes         No           Kenya      No  Employed part-time
# 1           3   Yes        Yes  United Kingdom      No  Employed full-time
# 2           4   Yes        Yes   United States      No  Employed full-time
#
#                             FormalEducation  \
# 0  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                          Associate degree
#
# ...

# %%
df.set_index('Respondent')
# Out:
#            Hobby OpenSource             Country         Student  \
# Respondent
# 1            Yes         No               Kenya              No
# 3            Yes        Yes      United Kingdom              No
# 4            Yes        Yes       United States              No
# 5             No         No       United States              No
# 7            Yes         No        South Africa  Yes, part-time
# ...          ...        ...                 ...             ...
# 101513       Yes        Yes       United States             NaN
# 101531        No        Yes               Spain  Yes, full-time
# 101541       Yes        Yes               India  Yes, full-time
# 101544       Yes         No  Russian Federation              No
# 101548       Yes        Yes            Cambodia             NaN
#
#                                                    Employment  \
# Respondent
# 1                                          Employed part-time
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.head(3)
# Out:
#    Respondent Hobby OpenSource         Country Student          Employment  \
# 0           1   Yes         No           Kenya      No  Employed part-time
# 1           3   Yes        Yes  United Kingdom      No  Employed full-time
# 2           4   Yes        Yes   United States      No  Employed full-time
#
#                             FormalEducation  \
# 0  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                          Associate degree
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
#
#                                              DevType       YearsCoding  \
# ...

# %%
df.shape
# Out:
# (98855, 129)

# %%
df.columns
# Out:
# Index(['Respondent', 'Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
#        ...
#        'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
#        'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=129)

# %%
df.describe()
# Out:
#           Respondent    AssessJob1    AssessJob2    AssessJob3    AssessJob4  \
# count   98855.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean    50822.971635      6.397089      6.673524      5.906875      4.065791
# std     29321.650410      2.788428      2.531202      2.642734      2.541196
# min         1.000000      1.000000      1.000000      1.000000      1.000000
# 25%     25443.500000      4.000000      5.000000      4.000000      2.000000
# 50%     50823.000000      7.000000      7.000000      6.000000      4.000000
# 75%     76219.500000      9.000000      9.000000      8.000000      6.000000
# max    101592.000000     10.000000     10.000000     10.000000     10.000000
#
#          AssessJob5    AssessJob6    AssessJob7    AssessJob8    AssessJob9  \
# count  66985.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean       3.953243      4.407196      5.673181      4.225200      7.640009
# ...

# %%
df.shape[0]
# Out:
# 98855

# %% [markdown]
# ## percentage of Nan values in each column

# %%
for col in df.columns: # 각 column마다
    print(f"{col}:\t{df[col].isnull().mean() * 100:.2f}%")
# Out:
# Respondent:	0.00%
# Hobby:	0.00%
# OpenSource:	0.00%
# Country:	0.42%
# Student:	4.00%
# Employment:	3.57%
# FormalEducation:	4.20%
# UndergradMajor:	20.05%
# CompanySize:	27.64%
# DevType:	6.84%
# YearsCoding:	5.08%
# YearsCodingProf:	21.19%
# JobSatisfaction:	29.92%
# CareerSatisfaction:	22.61%
# HopeFiveYears:	23.40%
# JobSearchStatus:	19.59%
# LastNewJob:	20.20%
# AssessJob1:	32.24%
# AssessJob2:	32.24%
# AssessJob3:	32.24%
# AssessJob4:	32.24%
# AssessJob5:	32.24%
# AssessJob6:	32.24%
# AssessJob7:	32.24%
# AssessJob8:	32.24%
# AssessJob9:	32.24%
# AssessJob10:	32.24%
# AssessBenefits1:	34.33%
# AssessBenefits2:	34.33%
# AssessBenefits3:	34.33%
# AssessBenefits4:	34.33%
# AssessBenefits5:	34.33%
# AssessBenefits6:	34.33%
# AssessBenefits7:	34.33%
# AssessBenefits8:	34.33%
# AssessBenefits9:	34.33%
# AssessBenefits10:	34.33%
# AssessBenefits11:	34.33%
# JobContactPriorities1:	50.73%
# JobContactPriorities2:	50.73%
# JobContactPriorities3:	50.73%
# JobContactPriorities4:	50.73%
# ...

# %%
x = 2.333
print(f"x = {x:.2f}")
# Out:
# x = 2.33

# %%
for col in df.columns:
  print(f"{col}:\t\t percentage of Nan values = {df[col].isnull().mean() * 100:.2f}%")
# Out:
# Respondent:		 percentage of Nan values = 0.00%
# Hobby:		 percentage of Nan values = 0.00%
# OpenSource:		 percentage of Nan values = 0.00%
# Country:		 percentage of Nan values = 0.42%
# Student:		 percentage of Nan values = 4.00%
# Employment:		 percentage of Nan values = 3.57%
# FormalEducation:		 percentage of Nan values = 4.20%
# UndergradMajor:		 percentage of Nan values = 20.05%
# CompanySize:		 percentage of Nan values = 27.64%
# DevType:		 percentage of Nan values = 6.84%
# YearsCoding:		 percentage of Nan values = 5.08%
# YearsCodingProf:		 percentage of Nan values = 21.19%
# JobSatisfaction:		 percentage of Nan values = 29.92%
# CareerSatisfaction:		 percentage of Nan values = 22.61%
# HopeFiveYears:		 percentage of Nan values = 23.40%
# JobSearchStatus:		 percentage of Nan values = 19.59%
# LastNewJob:		 percentage of Nan values = 20.20%
# AssessJob1:		 percentage of Nan values = 32.24%
# AssessJob2:		 percentage of Nan values = 32.24%
# ...

# %%
Num_Of_Nan = pd.DataFrame((df.isna().sum()/df.shape[0])*100)
Num_Of_Nan.rename(columns={0:'percentage'})
# Out:
#                percentage
# Respondent       0.000000
# Hobby            0.000000
# OpenSource       0.000000
# Country          0.416772
# Student          3.999798
# ...                   ...
# Age             34.678064
# Dependents      36.678974
# MilitaryUS      84.036215
# SurveyTooLong   33.295230
# SurveyEasy      33.357949
#
# [129 rows x 1 columns]

# %%
df_schema
# Out:
#             Column                                       QuestionText
# 0       Respondent  Randomized respondent ID number (not in order ...
# 1            Hobby                            Do you code as a hobby?
# 2       OpenSource         Do you contribute to open source projects?
# 3          Country          In which country do you currently reside?
# 4          Student  Are you currently enrolled in a formal, degree...
# ..             ...                                                ...
# 124            Age  What is your age? If you prefer not to answer,...
# 125     Dependents  Do you have any children or other dependents t...
# 126     MilitaryUS  Are you currently serving or have you ever ser...
# 127  SurveyTooLong  How do you feel about the length of the survey...
# 128     SurveyEasy  How easy or difficult was this survey to compl...
#
# [129 rows x 2 columns]

# %%
df_schema.loc[df_schema["Column"].str.contains("Edu")]
# Out:
#                Column                                       QuestionText
# 6     FormalEducation  Which of the following best describes the high...
# 58     EducationTypes  Which of the following types of non-degree edu...
# 122  EducationParents  What is the highest level of education receive...

# %%
df.AIFuture.value_counts()
# Out:
# I'm excited about the possibilities more than worried about the dangers.        50773
# I'm worried about the dangers more than I'm excited about the possibilities.    13269
# I don't care about it, or I haven't thought about it.                            5686
# Name: AIFuture, dtype: int64

# %%
df.head(5)
# Out:
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
#        ...
#        'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
#        'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=129)

# %%
df_subset = df[['Country','Salary']]
df_subset.sort_values(by = ['Country','Salary'] ,ascending=[True , True],inplace = True)
df_subset.head(20)
# Out:
# <ipython-input-140-c39f03c614dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values(by = ['Country','Salary'] ,ascending=[True , True],inplace = True)
#            Country  Salary
# 85714  Afghanistan       0
# 48645  Afghanistan       1
# 37543  Afghanistan  370000
# 85450  Afghanistan     500
# 62231  Afghanistan  700000
# 62608  Afghanistan  897989
# 5400   Afghanistan       9
# 602    Afghanistan     NaN
# 4633   Afghanistan     NaN
# 5498   Afghanistan     NaN
# 7592   Afghanistan     NaN
# 9019   Afghanistan     NaN
# 10362  Afghanistan     NaN
# 24752  Afghanistan     NaN
# 26910  Afghanistan     NaN
# 40299  Afghanistan     NaN
# 49321  Afghanistan     NaN
# 53445  Afghanistan     NaN
# 57822  Afghanistan     NaN
# 61259  Afghanistan     NaN

# %% [markdown]
# # number of particpationts who do their job as Hobby

# %%
df['Hobby'].value_counts(normalize=True)
# Out:
# Yes    0.808224
# No     0.191776
# Name: Hobby, dtype: float64

# %% [markdown]
# # countries in the survey

# %%
df['Country'].value_counts()
# Out:
# United States      20309
# India              13721
# Germany             6459
# United Kingdom      6221
# Canada              3393
#                    ...
# Sierra Leone           1
# Saint Lucia            1
# Solomon Islands        1
# Grenada                1
# Guinea-Bissau          1
# Name: Country, Length: 183, dtype: int64

# %%
20309/df['Country'].count()
# Out:
# 0.2063021240717979

# %%
df['Country'].value_counts(normalize=True)
# Out:
# United States      0.206302
# India              0.139380
# Germany            0.065612
# United Kingdom     0.063194
# Canada             0.034467
#                      ...
# Sierra Leone       0.000010
# Saint Lucia        0.000010
# Solomon Islands    0.000010
# Grenada            0.000010
# Guinea-Bissau      0.000010
# Name: Country, Length: 183, dtype: float64

# %%
from unicodedata import normalize
df.groupby(['Country']).get_group('India')['Age'].value_counts()
# Out:
# 25 - 34 years old     3562
# 18 - 24 years old     2590
# 35 - 44 years old      285
# Under 18 years old     122
# 45 - 54 years old       32
# 65 years or older        5
# 55 - 64 years old        3
# Name: Age, dtype: int64

# %%
country_gby = df.groupby(['Country']).get_group('Afghanistan')['Hobby'].value_counts()
country_gby
# Out:
# Yes    44
# No     20
# Name: Hobby, dtype: int64

# %%
country_gby = df.groupby(['Country'])
country_gby['Hobby'].value_counts(normalize=True).loc['Algeria']
# Out:
# Hobby
# Yes    0.769231
# No     0.230769
# Name: Hobby, dtype: float64

# %%
edu_columns = ["Student", "FormalEducation", "UndergradMajor", "YearsCoding"]
job_columns = ["Employment", "DevType", "LanguageWorkedWith"]
y = ["StackOverflowParticipate"]

edit_data = df[edu_columns + job_columns + y]

# %%
edit_data
# Out:
#               Student                                    FormalEducation  \
# 0                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                  No                                   Associate degree
# 3                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4      Yes, part-time  Some college/university study without earning ...
# ...               ...                                                ...
# 98850             NaN                                                NaN
# 98851  Yes, full-time                                                NaN
# 98852  Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 98853              No  Some college/university study without earning ...
# 98854             NaN                                                NaN
#
#                                           UndergradMajor       YearsCoding  \
# ...

# %% [markdown]
# ## the salary of the german engineers with 3-6 years experience

# %%
df.groupby('Country').get_group('Germany')['YearsCodingProf'].value_counts().loc['3-5 years']
# Out:
# 1517

# %%
mean_median_salary = df.groupby('Country')
mean_median_salary['ConvertedSalary'].mean()
# Out:
# Country
# Afghanistan                              62757.857143
# Albania                                  23347.638889
# Algeria                                  23676.538462
# Andorra                                 525089.500000
# Angola                                            NaN
#                                             ...
# Venezuela, Bolivarian Republic of...    241823.625000
# Viet Nam                                 19001.617284
# Yemen                                     8698.000000
# Zambia                                    1824.000000
# Zimbabwe                                 92951.428571
# Name: ConvertedSalary, Length: 183, dtype: float64

# %%
country_gby = df.groupby(['Country'])
country_gby['ConvertedSalary'].agg(['mean','median'])
# Out:
#                                                mean    median
# Country
# Afghanistan                            62757.857143    5324.0
# Albania                                23347.638889   11748.0
# Algeria                                23676.538462    7278.0
# Andorra                               525089.500000  525701.5
# Angola                                          NaN       NaN
# ...                                             ...       ...
# Venezuela, Bolivarian Republic of...  241823.625000    8100.0
# Viet Nam                               19001.617284    9516.0
# Yemen                                   8698.000000    8994.0
# Zambia                                  1824.000000    1824.0
# Zimbabwe                               92951.428571   14610.0
#
# [183 rows x 2 columns]

# %%
country_gby = df.groupby(['Country']).get_group('Afghanistan')
country_gby['ConvertedSalary'].mean()
# Out:
# 62757.857142857145

# %% [markdown]
# # how many people know python in egypt

# %%
df.groupby('Country').get_group('Afghanistan')['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 5

# %%
df=pd.DataFrame(df.groupby('Country').get_group('Egypt')['LanguageWorkedWith'].value_counts())
df
# Out:
#                                                 LanguageWorkedWith
# Java                                                             7
# JavaScript;PHP;SQL;HTML;CSS                                      5
# Java;SQL                                                         4
# JavaScript;PHP;HTML;CSS                                          4
# JavaScript;HTML;CSS                                              4
# ...                                                            ...
# C;C++;C#;Java;Python;SQL;VB.NET;HTML                             1
# C#;JavaScript;PHP;SQL;TypeScript;HTML;CSS                        1
# C++;C#;JavaScript;Matlab;PHP;SQL;HTML;CSS                        1
# JavaScript;Perl;Python;SQL;HTML;CSS;Bash/Shell                   1
# JavaScript;HTML;CSS;Bash/Shell                                   1
#
# [236 rows x 1 columns]

# %%
countryGroupBy = df.groupby('Country')
pythonics = countryGroupBy['LanguageWorkedWith'].apply(lambda x : x.str.contains('Python').sum())
pythonics
# Out:
# Country
# Afghanistan                              5
# Albania                                 21
# Algeria                                 20
# Andorra                                  1
# Angola                                   0
#                                         ..
# Venezuela, Bolivarian Republic of...    31
# Viet Nam                                52
# Yemen                                    0
# Zambia                                   3
# Zimbabwe                                 9
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %% [markdown]
# # number of people who took part in the servey in each country

# %%
particapations = pd.DataFrame(df['Country'].value_counts())
particapations
# Out:
#                  Country
# United States      20309
# India              13721
# Germany             6459
# United Kingdom      6221
# Canada              3393
# ...                  ...
# Sierra Leone           1
# Saint Lucia            1
# Solomon Islands        1
# Grenada                1
# Guinea-Bissau          1
#
# [183 rows x 1 columns]

# %%
python_df = pd.concat([particapations,pythonics] ,axis= 'columns',sort = False)
python_df
# Out:
#                  Country  LanguageWorkedWith
# United States      20309                8324
# India              13721                2830
# Germany             6459                2143
# United Kingdom      6221                2175
# Canada              3393                1340
# ...                  ...                 ...
# Sierra Leone           1                   1
# Saint Lucia            1                   1
# Solomon Islands        1                   0
# Grenada                1                   0
# Guinea-Bissau          1                   0
#
# [183 rows x 2 columns]

# %%
pythonic_percentage = (python_df['LanguageWorkedWith']*100)/python_df['Country']
pythonic_percentage
# Out:
# United States       40.986755
# India               20.625319
# Germany             33.178511
# United Kingdom      34.962225
# Canada              39.493074
#                       ...
# Sierra Leone       100.000000
# Saint Lucia        100.000000
# Solomon Islands      0.000000
# Grenada              0.000000
# Guinea-Bissau        0.000000
# Length: 183, dtype: float64

# %%
['pythonic_percentage'] = pythonic_percentagepython_df

# %%
python_df
# Out:
#                  Country  LanguageWorkedWith  pythonic_percentage
# United States      20309                8324            40.986755
# India              13721                2830            20.625319
# Germany             6459                2143            33.178511
# United Kingdom      6221                2175            34.962225
# Canada              3393                1340            39.493074
# ...                  ...                 ...                  ...
# Sierra Leone           1                   1           100.000000
# Saint Lucia            1                   1           100.000000
# Solomon Islands        1                   0             0.000000
# Grenada                1                   0             0.000000
# Guinea-Bissau          1                   0             0.000000
#
# [183 rows x 3 columns]

# %%
python_df.sort_values(by='pythonic_percentage' ,ascending=False,inplace = True)
python_df
# Out:
#                Country  LanguageWorkedWith  pythonic_percentage
# Burundi              1                   1                100.0
# Sierra Leone         1                   1                100.0
# Saint Lucia          1                   1                100.0
# Liechtenstein        5                   3                 60.0
# North Korea          4                   2                 50.0
# ...                ...                 ...                  ...
# Eritrea              1                   0                  0.0
# Djibouti             1                   0                  0.0
# Belize               1                   0                  0.0
# Bhutan               6                   0                  0.0
# Guinea-Bissau        1                   0                  0.0
#
# [183 rows x 3 columns]

# %%
python_df.loc['Burundi']
# Out:
# Country                  1.0
# LanguageWorkedWith       1.0
# pythonic_percentage    100.0
# Name: Burundi, dtype: float64

# %% [markdown]
# # Top 10 countries who works with python

# %%
python_df['LanguageWorkedWith'].nlargest(10)
# Out:
# United States         8324
# India                 2830
# United Kingdom        2175
# Germany               2143
# Canada                1340
# France                 876
# Russian Federation     798
# Brazil                 693
# Australia              686
# Netherlands            620
# Name: LanguageWorkedWith, dtype: int64
